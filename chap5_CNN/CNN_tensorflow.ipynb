# %%
import tensorflow as tf
from  keras import layers, models

# 1. 加载数据
(x_train, y_train), (x_test, y_test) = tf.keras.datasets.mnist.load_data()

# 2. 数据预处理
x_train = x_train.reshape(-1, 28, 28, 1) / 255.0
x_test = x_test.reshape(-1, 28, 28, 1) / 255.0

# one-hot
y_train = tf.keras.utils.to_categorical(y_train, 10)
y_test = tf.keras.utils.to_categorical(y_test, 10)

# 3. 构建模型 
model = models.Sequential([
    # Conv1
    layers.Conv2D(32, (7,7), padding='same', activation='relu', input_shape=(28,28,1)),
    layers.MaxPooling2D((2,2), padding='same'),

    # Conv2
    layers.Conv2D(64, (5,5), padding='same', activation='relu'),
    layers.MaxPooling2D((2,2), padding='same'),

    # FC1
    layers.Flatten(),
    layers.Dense(1024, activation='relu'),
    layers.Dropout(0.3),   # keep_prob=0.7 → dropout=0.3

    # FC2
    layers.Dense(10, activation='softmax')
])

# 4. 编译
model.compile(
    optimizer=tf.keras.optimizers.Adam(learning_rate=1e-4),
    loss='categorical_crossentropy',
    metrics=['accuracy']
)

# 5. 训练
model.fit(
    x_train, y_train,
    batch_size=100,
    epochs=10,          # TF2不需要2000次iteration，用epoch
    validation_data=(x_test, y_test)
)

# 6. 测试
test_loss, test_acc = model.evaluate(x_test, y_test)
print("Test accuracy:", test_acc)
# Out:
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1774179439.249459  139791 cpu_feature_guard.cc:227] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# /workspaces/exercise/venv/lib/python3.12/site-packages/keras/src/layers/convolutional/base_conv.py:113: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Epoch 1/10
# W0000 00:00:1774179449.863966  139791 cpu_allocator_impl.cc:82] Allocation of 188160000 exceeds 10% of free system memory.
# W0000 00:00:1774179454.990094  143033 cpu_allocator_impl.cc:82] Allocation of 22579200 exceeds 10% of free system memory.
#   1/600 ━━━━━━━━━━━━━━━━━━━━ 52:43 5s/step - accuracy: 0.0700 - loss: 2.3240
# W0000 00:00:1774179455.294984  143032 cpu_allocator_impl.cc:82] Allocation of 18593344 exceeds 10% of free system memory.
# W0000 00:00:1774179455.844660  143032 cpu_allocator_impl.cc:82] Allocation of 22579200 exceeds 10% of free system memory.
#   2/600 ━━━━━━━━━━━━━━━━━━━━ 9:10 920ms/step - accuracy: 0.0875 - loss: 2.3168
# W0000 00:00:1774179456.194778  143032 cpu_allocator_impl.cc:82] Allocation of 18593344 exceeds 10% of free system memory.
# 600/600 ━━━━━━━━━━━━━━━━━━━━ 146s 236ms/step - accuracy: 0.8934 - loss: 0.3804 - val_accuracy: 0.9667 - val_loss: 0.1119
# Epoch 2/10
# 600/600 ━━━━━━━━━━━━━━━━━━━━ 189s 218ms/step - accuracy: 0.9690 - loss: 0.1027 - val_accuracy: 0.9811 - val_loss: 0.0610
# Epoch 3/10
# 600/600 ━━━━━━━━━━━━━━━━━━━━ 126s 210ms/step - accuracy: 0.9790 - loss: 0.0696 - val_accuracy: 0.9842 - val_loss: 0.0487
# Epoch 4/10
# 600/600 ━━━━━━━━━━━━━━━━━━━━ 132s 219ms/step - accuracy: 0.9837 - loss: 0.0549 - val_accuracy: 0.9866 - val_loss: 0.0424
# Epoch 5/10
# 600/600 ━━━━━━━━━━━━━━━━━━━━ 131s 218ms/step - accuracy: 0.9863 - loss: 0.0446 - val_accuracy: 0.9887 - val_loss: 0.0355
# Epoch 6/10
# 600/600 ━━━━━━━━━━━━━━━━━━━━ 139s 212ms/step - accuracy: 0.9887 - loss: 0.0378 - val_accuracy: 0.9894 - val_loss: 0.0317
# Epoch 7/10
# 600/600 ━━━━━━━━━━━━━━━━━━━━ 127s 211ms/step - accuracy: 0.9896 - loss: 0.0337 - val_accuracy: 0.9919 - val_loss: 0.0266
# Epoch 8/10
# 600/600 ━━━━━━━━━━━━━━━━━━━━ 132s 220ms/step - accuracy: 0.9911 - loss: 0.0289 - val_accuracy: 0.9896 - val_loss: 0.0314
# Epoch 9/10
# 600/600 ━━━━━━━━━━━━━━━━━━━━ 140s 217ms/step - accuracy: 0.9920 - loss: 0.0255 - val_accuracy: 0.9913 - val_loss: 0.0258
# Epoch 10/10
# 600/600 ━━━━━━━━━━━━━━━━━━━━ 143s 219ms/step - accuracy: 0.9930 - loss: 0.0220 - val_accuracy: 0.9914 - val_loss: 0.0233
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 6s 20ms/step - accuracy: 0.9914 - loss: 0.0233
# Test accuracy: 0.9914000034332275
